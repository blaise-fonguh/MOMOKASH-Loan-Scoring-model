# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import datetime as dt
import time
from dateutil.relativedelta import relativedelta

# %%
Client = MongoClient("mongodb://3.20.189.28:2036/momoKashBd?readPreference=secondary&directConnection=true")
db_loan = Client["momoKashBd"]
Loans = db_loan["Loan"]
print("MongoDB connection established with success")

# Define start and end of iteration
current_date = dt.datetime(2025, 10, 1)
final_date = dt.datetime(2025, 10, 31)

while current_date <= final_date:
    date_start = current_date
    date_end = date_start + relativedelta(months=1) - dt.timedelta(days=1)

    print(f"\nProcessing loans from {date_start.strftime('%B %Y')}...")

    start = time.time()

    cursor = Loans.find(
        { 
            "dateTime": {"$gte": date_start, "$lte": date_end},
        },
        {
            "_id": 1, 
            "loanAmount" : 1,
            "amountPaid" : 1,
            "dueDate" : 1,
            "loanDate" : 1,
            "dueAmount" :1,
            "amountwithInterest" : 1,
            "loanStatus" : 1,
            "interest_rate" : 1,
            "clientID" : 1, 
            "bonusAmount" : 1,
            "penaltyAmounnt": 1,
            "amountDisbursed" : 1,  
            "totalDueAmount" : 1,
            "dateTime": 1
        })

    loans_df = pd.DataFrame(list(cursor))

    if loans_df.empty:
        print("No completed loans were made during this period.")
    else:
        for col in ["loanDate", "dueDate"]:
            loans_df[col] = pd.to_datetime(loans_df[col], dayfirst=True, errors="coerce")

        loans_df = loans_df.sort_values("dateTime", ascending=True)

        # Clean fields
        date_cols = ["loanDate", "dueDate"]
        for col in date_cols:
            loans_df[col] = pd.to_datetime(loans_df[col], dayfirst=True, errors="coerce")

        req_fields = ["dueAmount", "penaltyAmount"]
        for col in req_fields:
            if col not in loans_df.columns:
                loans_df[col] = 0
            else:
                loans_df[col] = loans_df[col].fillna(0)

        num_cols = ["loanAmount", "amountPaid", "amountwithInterest", "interest_rate",
                    "is_complete", "bonusAmount", "amountDisbursed", "totalDueAmount"]
        for col in num_cols:
            if col in loans_df.columns:
                loans_df[col] = loans_df[col].fillna(0).apply(lambda x: max(x, 0))

        text_cols = ["loanStatus", "clientID"]
        for col in text_cols:
            if col in loans_df.columns:
                loans_df[col] = loans_df[col].astype(str).str.strip()

        loans_df.index = np.arange(loans_df.shape[0])
        loans_df = loans_df.sort_values("loanDate", ascending=True)

        print("Sample of fully cleaned refunds:")
        print(loans_df.head(3))

        # Export CSV
        filename = f"loans_{date_start.strftime('%b_%Y').lower()}.csv"
        loans_df.to_csv(filename, index=False, sep=",")
        print(f"CSV export of {filename} complete")

    end = time.time()
    print(f"Fetching time: {round((end-start)/60, 2)} minutes")

    # Move to next month
    current_date += relativedelta(months=1)
# Out:
# MongoDB connection established with success
#
# Processing loans from October 2025...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 40
#      16 start = time.time()
#      18 cursor = Loans.find(
#      19     {
#      20         "dateTime": {"$gte": date_start, "$lte": date_end},
#    (...)
#      37         "dateTime": 1
#      38     })
# ---> 40 loans_df = pd.DataFrame(list(cursor))
#      42 if loans_df.empty:
#      43     print("No completed loans were made during this period.")
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\cursor.py:1236, in Cursor._refresh(self)
#    1221     # Exhaust cursors don't send getMore messages.
#    1222     g = self._getmore_class(
#    1223         self._dbname,
#    1224         self._collname,
#    (...)
#    1234         self._comment,
#    1235     )
# -> 1236     self._send_message(g)
#    1238 return len(self._data)
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)
#    1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\mongo_client.py:2926, in _ClientConnectionRetryable._read(self)
#    2918 if self._retrying:
#    2919     _debug_log(
#    2920         _COMMAND_LOGGER,
#    2921         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)
#    2924         operationId=self._operation_id,
#    2925     )
# -> 2926 return self._func(self._session, self._server, conn, read_pref)
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\mongo_client.py:1929, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1922 def _cmd(
#    1923     _session: Optional[ClientSession],
#    1924     server: Server,
#    1925     conn: Connection,
#    1926     read_preference: _ServerMode,
#    1927 ) -> Response:
#    1928     operation.reset()  # Reset op in case of retry.
# -> 1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    1932         read_preference,
#    1933         self._event_listeners,
#    1934         unpack_res,
#    1935         self,
#    1936     )
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\pool.py:508, in Connection.receive_message(self, request_id)
#     506 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     507 except BaseException as error:
# --> 508     self._raise_connection_failure(error)
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\synchronous\pool.py:505, in Connection.receive_message(self, request_id)
#     500 """Receive a raw BSON message or raise ConnectionFailure.
#     501
#     502 If any exception is raised, the socket is closed.
#     503 """
#     504 try:
# --> 505     return receive_message(self, request_id, self.max_message_size)
#     506 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     507 except BaseException as error:
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\network_layer.py:677, in receive_message(conn, request_id, max_message_size)
#     675     data = decompress(receive_data(conn, length - 25, deadline), compressor_id)
#     676 else:
# --> 677     data = receive_data(conn, length - 16, deadline)
#     679 try:
#     680     unpack_reply = _UNPACK_REPLY[op_code]
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\network_layer.py:124, in receive_data(conn, length, deadline)
#     120 try:
#     121     # Use the legacy wait_for_read cancellation approach on PyPy due to PYTHON-5011.
#     122     # also use it on Windows due to PYTHON-5405
#     123     if _PYPY or _WINDOWS:
# --> 124         wait_for_read(conn, deadline)
#     125         if _csot.get_timeout() and deadline is not None:
#     126             conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\network_layer.py:97, in wait_for_read(conn, deadline)
#      95     else:
#      96         timeout = _POLL_TIMEOUT
# ---> 97     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#      98 if conn.cancel_context.cancelled:
#      99     raise _OperationCancelled("operation cancelled")
#
# File D:\apps\anaconda\Lib\site-packages\pymongo\socket_checker.py:77, in SocketChecker.select(self, sock, read, write, timeout)
#      75 rlist = [sock] if read else []
#      76 wlist = [sock] if write else []
# ---> 77 res = select.select(rlist, wlist, [sock], timeout)
#      78 # select returns a 3-tuple of lists of objects that are
#      79 # ready: subsets of the first three arguments. Return
#      80 # True if any of the lists are not empty.
#      81 return any(res)
#
# KeyboardInterrupt:

# %%
Client = MongoClient("mongodb://3.20.189.28:2036/momoKashBd?readPreference=secondary&directConnection=true")
db_loan = Client["momoKashBd"]
Loans = db_loan["Loan"]
print("MongoDB connection established with success")
df = pd.read_csv('merged_loans_all.csv')  # Or .csv if that's your file format
# Create a new column for MongoDB _id
mongo_ids = []

for idx, row in df.iterrows():
    query = {
        "clientID": row["clientID"],
        "loanDate": row["loanDate"],
        "amountDisbursed": row["amountDisbursed"]  # Add other fields for more accurate matches if necessary
    }
    doc = Loans.find_one(query)
    if doc and '_id' in doc:
        mongo_ids.append(str(doc['_id']))  # Convert ObjectId to string
    else:
        mongo_ids.append(None)  # Or 'Not found'

# Add this as a new column to the DataFrame
df["mongo_id"] = mongo_ids

df.to_excel('merged_loans_with_id.csv', index=False)
# Out:
# MongoDB connection established with success
# KeyboardInterrupt
